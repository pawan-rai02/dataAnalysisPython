# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast

dataset= load_dataset('lukebarousse/data_jobs')
df= dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DE_ind = df[(df['job_title_short'] == 'Data Engineer') & (df['job_country'] == 'India')].copy()
df_DE_ind
# Out:
#        job_title_short                                          job_title  \
# 16       Data Engineer                                  Big Data Engineer
# 80       Data Engineer  Director - Enterprise Architecture and Data En...
# 95       Data Engineer                                      Data Engineer
# 149      Data Engineer                              Data Engineering Lead
# 210      Data Engineer                                Azure Data Engineer
# ...                ...                                                ...
# 785584   Data Engineer                                      Data Engineer
# 785636   Data Engineer                                      Data Engineer
# 785684   Data Engineer                                      Data Engineer
# 785695   Data Engineer                                  AWS Data Engineer
# 785712   Data Engineer                     India - Collections Analyst II
#
#                        job_location                         job_via  \
# ...

# %%
df_DE_ind['salary_year_avg'].plot(kind='hist', bins=20, edgecolor='black')
plt.xlim(20000, 200000)


ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x/1000)}K'))



plt.ylabel('Number of Job Postings')    
plt.xlabel('Average Yearly Salary (INR)')
plt.title('Histogram of Average Yearly Salary for Data Engineers in India')
# Out:
# Text(0.5, 1.0, 'Histogram of Average Yearly Salary for Data Engineers in India')
